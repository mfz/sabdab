# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

from ydata_profiling import ProfileReport

# %%
abag = pd.read_csv('ab_ag.tsv', sep = '\t')
columns = pd.read_csv('columns.tsv', sep = '\t')

# %%
pd.options.display.max_rows = None

abag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5523 entries, 0 to 5522
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pdb               5523 non-null   object
#  1   Hchain            5481 non-null   object
#  2   Lchain            5344 non-null   object
#  3   model             5523 non-null   int64
#  4   antigen_chain     5490 non-null   object
#  5   antigen_type      5490 non-null   object
#  6   antigen_het_name  694 non-null    object
#  7   antigen_name      5490 non-null   object
#  8   short_header      5520 non-null   object
#  9   date              5523 non-null   object
#  10  compound          5523 non-null   object
#  11  organism          5522 non-null   object
#  12  heavy_species     5466 non-null   object
#  13  light_species     4938 non-null   object
#  14  antigen_species   5471 non-null   object
#  15  authors           5523 non-null   object
# ...

# %%
# Do not truncate long columns
pd.set_option('display.max_colwidth', None)

columns
# Out:
#                                                                                                                                                                                                                                                                                                                                   Name    Description
# PDB                                                                                                                                                                                                                                                                                                                The PDB accession code (e.g. 12e8)
# ...

# %%
profile = ProfileReport(abag, title="YData Profiling Report")

# %%
profile.to_file("profile_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
abag.head(3).T
# Out:
#                                                                   0  \
# pdb                                                            9ds2
# Hchain                                                            G
# Lchain                                                            I
# model                                                             0
# antigen_chain                                                 D | C
# antigen_type                                      protein | protein
# antigen_het_name                                            NA | NA
# antigen_name       hemagglutinin ha2 chain | hemagglutinin ha1 chai
# short_header                            VIRAL PROTEIN/IMMUNE SYSTEM
# date                                                       03/19/25
# compound          Crystal structure of 346-54 Fab in complex wit...
# organism                            Homo sapiens; Influenza A virus
# heavy_species                                          homo sapiens
# ...

# %%
abag.describe().T
# Out:
#              count          mean           std     min           25%  \
# model       5523.0  2.715915e-03  9.976363e-02   0.000  0.000000e+00
# resolution  5523.0  2.760820e+00  9.602936e-01   0.000  2.491500e+00
# r_free      2821.0  2.604943e-01  3.296918e-02   0.169  2.370000e-01
# r_factor    2821.0  2.179920e-01  3.175182e-02   0.138  1.960000e-01
# affinity     142.0  1.227181e-07  5.766834e-07   0.000  1.075000e-09
# delta_g      125.0 -1.140528e+01  1.571470e+00 -15.540 -1.227000e+01
# pmid         122.0  1.869092e+07  3.638515e+06  25.000  1.782584e+07
#
#                      50%           75%           max
# model       0.000000e+00  0.000000e+00  5.000000e+00
# resolution  2.990000e+00  3.400000e+00  4.000000e+00
# r_free      2.590000e-01  2.810000e-01  4.580000e-01
# r_factor    2.150000e-01  2.350000e-01  4.410000e-01
# affinity    6.970000e-09  4.400000e-08  4.700000e-06
# delta_g    -1.150000e+01 -1.034000e+01 -7.260000e+00
# ...

# %%
abag.select_dtypes(include=['object']).describe().T
# Out:
#                  count unique  \
# pdb               5523   2675
# Hchain            5481     54
# Lchain            5344     50
# antigen_chain     5490    203
# antigen_type      5490     12
# antigen_het_name   694      5
# antigen_name      5490    808
# short_header      5520    172
# date              5523   1007
# compound          5523   2590
# organism          5522    412
# heavy_species     5466      1
# light_species     4938      1
# antigen_species   5471    350
# authors           5523   1389
# method            5523      3
# heavy_subclass    5483     12
# light_subclass    5344     30
# light_ctype       5344      3
# affinity_method    142     12
# temperature         80      7
#
#                                                                 top  freq
# pdb                                                            6vmk    16
# Hchain                                                            H  1757
# ...

# %%
abag["method"].value_counts(dropna=False)
# Out:
# method
# X-RAY DIFFRACTION                       2821
# ELECTRON MICROSCOPY                     2692
# ELECTRON MICROSCOPY / HOMOLOGY MODEL      10
# Name: count, dtype: int64

# %%
abag["antigen_type"].value_counts(dropna=False)
# Out:
# antigen_type
# protein                                  4790
# protein | protein                         568
# protein | protein | protein                65
# protein | peptide                          42
# NaN                                        33
# peptide | protein                           7
# peptide                                     6
# carbohydrate                                4
# protein | protein | peptide                 3
# protein | protein | protein | peptide       2
# peptide | protein | protein                 1
# protein | peptide | protein                 1
# carbohydrate | protein | protein            1
# Name: count, dtype: int64

# %%
abag["antigen_het_name"].value_counts(dropna=False)
# Out:
# antigen_het_name
# NaN                  4829
# NA | NA               617
# NA | NA | NA           70
# MAN                     4
# NA | NA | NA | NA       2
# NAG | NA | NA           1
# Name: count, dtype: int64

# %%
abag.query("method == 'X-RAY DIFFRACTION'").head(3).T
# Out:
#                                                                                                       0  \
# pdb                                                                                                9ds2
# Hchain                                                                                                G
# Lchain                                                                                                I
# model                                                                                                 0
# antigen_chain                                                                                     D | C
# antigen_type                                                                          protein | protein
# antigen_het_name                                                                                NA | NA
# antigen_name                                           hemagglutinin ha2 chain | hemagglutinin ha1 chai
# ...

# %%
abag.select_dtypes(include='number').corr()
# Out:
#                model  resolution    r_free  r_factor  affinity   delta_g  \
# model       1.000000    0.035136       NaN       NaN       NaN       NaN
# resolution  0.035136    1.000000  0.609114  0.562403 -0.115790 -0.136652
# r_free           NaN    0.609114  1.000000  0.908767 -0.193898 -0.188124
# r_factor         NaN    0.562403  0.908767  1.000000 -0.241747 -0.192254
# affinity         NaN   -0.115790 -0.193898 -0.241747  1.000000  0.417825
# delta_g          NaN   -0.136652 -0.188124 -0.192254  0.417825  1.000000
# pmid             NaN    0.087266 -0.086582  0.034652  0.019283  0.073848
#
#                 pmid
# model            NaN
# resolution  0.087266
# r_free     -0.086582
# r_factor    0.034652
# affinity    0.019283
# delta_g     0.073848
# pmid        1.000000

# %%
abag["Hchain"].value_counts().sort_values(ascending=False).iloc[0:10].plot(kind='bar')
plt.show()

# %%
#abag.resolution.plot(kind='hist', bins=50)

plt.hist(abag.resolution, bins=20);

# %%
f, a = plt.subplots(1,2)
a[0].scatter([1,2,3,4], [4,5,6,3])
a[1].bar([1,2,3,4], [4,5,6,3])

f.suptitle("Test")
a[0].set_xlabel("x")
a[0].set_ylabel("y")
a[0].set_title("title")
# Out:
# Text(0.5, 1.0, 'title')
